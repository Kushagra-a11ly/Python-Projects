# %%
class EmojiMoodDetector:

    def __init__(self):
        self.mood_keywords = {

            "happy": ["happy", "joy", "joyful", "cheerful", "delighted", "glad", "bliss", "content", "pleased",
                      "ecstatic", "jolly", "uplifted", "bright", "radiant", "lighthearted", "overjoyed"],

            "sad": ["sad", "unhappy", "down", "depressed", "sorrow", "crying", "blue", "heartbroken", "miserable",
                    "gloomy", "grief", "sinking", "disappointed", "melancholy"],

            "angry": ["angry", "mad", "furious", "irritated", "annoyed", "rage", "frustrated", "outraged",
                      "heated", "fuming", "resentful", "provoked", "hostile"],

            "excited": ["excited", "thrilled", "eager", "enthusiastic", "pumped", "energetic", "hyped", "animated",
                        "delighted", "fired up"],

            "tired": ["tired", "sleepy", "exhausted", "fatigued", "drained", "worn out", "drowsy", "lazy",
                      "weary", "low energy"],

            "love": ["love", "loving", "affection", "romantic", "fond", "passionate", "crush", "adore",
                     "attached", "devoted"],

            "confused": ["confused", "puzzled", "uncertain", "unsure", "lost", "mixed up", "chaotic", "unclear",
                         "foggy"],

            "scared": ["scared", "fear", "afraid", "terrified", "nervous", "anxious", "worried", "panicked",
                       "uneasy", "alarmed"],

            "bored": ["bored", "dull", "uninterested", "monotonous", "tired of", "fed up", "bland"],

            "surprised": ["surprised", "shocked", "amazed", "astonished", "startled", "speechless", "mind blown"],

            "calm": ["calm", "peaceful", "relaxed", "serene", "balanced", "chill", "still", "at ease",
                     "centered"],

            "proud": ["proud", "accomplished", "satisfied", "victorious", "fulfilled", "successful"],

            "motivated": ["motivated", "determined", "focused", "driven", "ambitious", "inspired", "goal oriented"],

            "shy": ["shy", "timid", "bashful", "sheepish", "reserved", "quiet"],

            "jealous": ["jealous", "envious", "covet", "resentful"],

            "embarrassed": ["embarrassed", "ashamed", "awkward", "cringe", "self conscious", "mortified"],

            "lonely": ["lonely", "isolated", "alone", "abandoned", "empty", "friendless"],

            "grateful": ["grateful", "thankful", "appreciative", "blessed", "obliged"],

            "hopeful": ["hopeful", "optimistic", "expecting", "positive"],

            "stressed": ["stressed", "pressure", "overwhelmed", "tense", "strained"],

            "sick": ["sick", "ill", "nauseous", "unwell", "fever", "cold", "flu"],

            "hungry": ["hungry", "starving", "craving", "famished"],

            "confident": ["confident", "bold", "fearless", "strong", "assured"],

            "lazy": ["lazy", "unmotivated", "sluggish", "idle", "inactive"],

            "focused": ["focused", "sharp", "concentrated", "attentive"],

            "relieved": ["relieved", "comforted", "released", "unburdened"],

            "guilty": ["guilty", "regret", "remorse", "sorry"],

            "creative": ["creative", "imaginative", "artistic", "inventive"],
        }
        
        self.mood_emojis = {
            "happy": "🙂",
            "sad": "😢",
            "angry": "😡",
            "excited": "🤩",
            "tired": "😴",
            "love": "😍",
            "confused": "😕",
            "scared": "😱",
            "bored": "🥱",
            "surprised": "😲",
            "calm": "😌",
            "proud": "😎",
            "motivated": "💪",
            "shy": "😊",
            "jealous": "😒",
            "embarrassed": "😳",
            "lonely": "🥺",
            "grateful": "🙏",
            "hopeful": "🌈",
            "stressed": "😫",
            "sick": "🤒",
            "hungry": "🍽️",
            "confident": "😤",
            "lazy": "🛌",
            "focused": "🎯",
            "relieved": "😌",
            "guilty": "😔",
            "creative": "🎨"
        }

    def detect_mood(self, user_input):

        text = user_input.lower()

        for mood, keywords in self.mood_keywords.items():
            for word in keywords:
                if word in text:
                    return mood

        return None

    def run(self):
        print("=== Emoji Mood Detector ===")
        user_mood = input("Describe your feeling: ")

        mood = self.detect_mood(user_mood)

        if mood:
            print(f"Emotion detected → {mood.capitalize()} {self.mood_emojis[mood]}")
        else:
            print("I couldn't detect your emotion 😶")
            print("Try words like:")
            print(", ".join(self.mood_emojis.keys()))


detector = EmojiMoodDetector()
detector.run()
# Out:
# === Emoji Mood Detector ===
# Emotion detected → Calm 😌
